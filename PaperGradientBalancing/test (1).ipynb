# %%
import cv2
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15, 15))
plt.xticks([])
plt.yticks([])
sns.heatmap(cv2.imread('23.bmp', cv2.IMREAD_GRAYSCALE), cbar=False)
